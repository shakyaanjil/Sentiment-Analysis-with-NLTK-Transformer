# %%
import nltk
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('ggplot')

# %%
#load_data
df = pd.read_csv('sampled_reviews.csv')

# %% [markdown]
# ### Data Summary

# %%
print("Shape of the data:", df.shape)
print("Data types:\n", df.dtypes)
print("Missing values:\n", df.isnull().sum())
# Out:
# Shape of the data: (1000, 10)
# Data types:
#  Id                         int64
# ProductId                 object
# UserId                    object
# ProfileName               object
# HelpfulnessNumerator       int64
# HelpfulnessDenominator     int64
# Score                      int64
# Time                       int64
# Summary                   object
# Text                      object
# dtype: object
# Missing values:
#  Id                        0
# ProductId                 0
# UserId                    0
# ProfileName               0
# HelpfulnessNumerator      0
# HelpfulnessDenominator    0
# Score                     0
# Time                      0
# Summary                   0
# Text                      0
# dtype: int64

# %% [markdown]
# ### Statistical Summary

# %%
print("Descriptive statistics:\n", df.describe())
# Out:
# Descriptive statistics:
#                    Id  HelpfulnessNumerator  HelpfulnessDenominator  \
# count    1000.000000           1000.000000             1000.000000
# mean   277980.597000              1.441000                2.021000
# std    158770.244875              3.357647                4.324495
# min        10.000000              0.000000                0.000000
# 25%    142067.000000              0.000000                0.000000
# 50%    274783.000000              0.000000                1.000000
# 75%    415168.250000              2.000000                2.000000
# max    567423.000000             41.000000               50.000000
#
#              Score          Time
# count  1000.000000  1.000000e+03
# mean      4.131000  1.297379e+09
# std       1.357085  4.888527e+07
# min       1.000000  1.066090e+09
# 25%       4.000000  1.274227e+09
# 50%       5.000000  1.313539e+09
# 75%       5.000000  1.333346e+09
# max       5.000000  1.351210e+09

# %% [markdown]
# ### Visualization|

# %% [markdown]
# #### Histograms

# %%
df.hist(figsize=(12, 10))
plt.show()

# %% [markdown]
# #### Boxplots

# %%
df.boxplot(figsize=(12, 10))
plt.show()

# %% [markdown]
# ### Distribution Analysis

# %% [markdown]
# #### Kernal Density Plots

# %%
sns.kdeplot(df['Score'])
plt.show()

# %% [markdown]
# #### Pair Plots

# %%
sns.pairplot(df)
plt.show()

# %% [markdown]
# ### Outliers Detection

# %% [markdown]
# #### Boxplots

# %%
sns.boxplot(df['Score'])
plt.show()

# %% [markdown]
# #### Z-Score

# %%
from scipy.stats import zscore
df['zscore'] = zscore(df['Score'])
print(df['zscore'].head())
# Out:
# 0    0.640663
# 1    0.640663
# 2    0.640663
# 3    0.640663
# 4    0.640663
# Name: zscore, dtype: float64
